# %%
qq= "WISHINGYOUGOODLUCKINTHISCOURSEANDALLOTHERCOURSESOFYOURPROGRAMABC"
a=qq.lower()

 
hexblocks = "0x"
count=0
kk=1 


for j in range(len(a)):     
        m = a[j]
        b=ord(m)-97         
      
        if kk>0:
            x = b
            c = hex(x)
         
        if x < 16 :
            hexblocks +='0'
            hexblocks +=c[2]
        else:
            hexblocks +=c[2]
            hexblocks +=c[3]
        if count == 7 and j < (len(a)-1):         
            hexblocks +=", 0x"
            count=0
        else:
            count +=1
            
print(hexblocks) 

from sage.crypto.block_cipher.des import DES 
des = DES()
plaintext=[0x16081207080d0618, 0x0e14060e0e030b14, 0x020a080d13070812, 0x020e14111204000d, 0x03000b0b0e130704, 0x11020e1411120412, 0x0e05180e14110f11, 0x0e0611000c191919]
key = 0x1F08260D1AC246E

def encrypt_des(plaintext, key): 
    p=plaintext
    k=key 
    ciphertext= ""

    for i in range (len(p)):
        c = des.encrypt(plaintext=p[i], key=k); 
        ciphertext += c.hex()
        ciphertext += ' '
    return ciphertext

encrypt_des(plaintext, key)

def decrypt_des(ciphertext, key):
    c=ciphertext
    k=key 
    plaintext= "0x"

    for i in range (len(c)):
        p = des.decrypt(ciphertext=c[i], key=k) 
        plaintext += p.hex()
        if i < (len(c)-1):
            plaintext += ', 0x' 
    return plaintext
ciphertext = [0xbe04aa776012718, 0x97eba93e1f59b88b, 0x4c67a13e0ac68d6a, 0x1b0e709c3e8dd55d, 0x64873df30f0092b1, 0x5bd820e90db96ec9, 0x14fc52b5446b1ba8, 0x5485af6f9884ab83]
key = 0x1F08260D1AC246E

decrypt_des(ciphertext, key)

from sage.crypto.block_cipher.des import DES_KS 
ks = DES_KS()
key = 0x1F08260D1AC246E
[ k.hex() for k in ks(key) ]


from sage.crypto.block_cipher.des import DES
from sage.crypto.block_cipher.des import convert_to_vector 
des = DES()
block= 0x16081207080d0618
block = convert_to_vector(block, 64)
#print(block)
### initial permutation
ip = des._ip(block)
#print(ip == block)
#print(ip)
##### Final permutation of the ip
fp= des._inv_ip(ip)
### check if fp= block fp == block
fp == block
# Out:
# 0x16081207080d0618, 0x0e14060e0e030b14, 0x020a080d13070812, 0x020e14111204000d, 0x03000b0b0e130704, 0x11020e1411120412, 0x0e05180e14110f11, 0x0e0611000c000102
# True

# %%
from sage.crypto.block_cipher.des import DES 
des = DES()
plaintext=[0x16081207080d0618, 0x0e14060e0e030b14, 0x020a080d13070812, 0x020e14111204000d, 0x03000b0b0e130704, 0x11020e1411120412, 0x0e05180e14110f11, 0x0e0611000c191919]
key = 0x1F08260D1AC246E

def encrypt_des(plaintext, key): 
    p=plaintext
    k=key 
    ciphertext= ""

    for i in range (len(p)):
        c = des.encrypt(plaintext=p[i], key=k); 
        ciphertext += c.hex()
        ciphertext += ' '
    return ciphertext

encrypt_des(plaintext, key)

def decrypt_des(ciphertext, key):
    c=ciphertext
    k=key 
    plaintext= "0x"

    for i in range (len(c)):
        p = des.decrypt(ciphertext=c[i], key=k) 
        plaintext += p.hex()
        if i < (len(c)-1):
            plaintext += ', 0x' 
    return plaintext
ciphertext = [0xbe04aa776012718, 0x97eba93e1f59b88b, 0x4c67a13e0ac68d6a, 0x1b0e709c3e8dd55d, 0x64873df30f0092b1, 0x5bd820e90db96ec9, 0x14fc52b5446b1ba8, 0x5485af6f9884ab83]
key = 0x1F08260D1AC246E

decrypt_des(ciphertext, key)
# Out:
# '0x16081207080d0618, 0xe14060e0e030b14, 0x20a080d13070812, 0x20e14111204000d, 0x3000b0b0e130704, 0x11020e1411120412, 0xe05180e14110f11, 0xe0611000c191919'

# %%
qq= "WISHINGYOUGOODLUCKINTHISCOURSEANDALLOTHERCOURSESOFYOURPROGRAMABC"
a=qq.lower()

 
hexblocks = "0x"
count=0
kk=1 


for j in range(len(a)):     
        m = a[j]
        b=ord(m)-97         
      
        if kk>0:
            x = b
            c = hex(x)
         
        if x < 16 :
            hexblocks +='0'
            hexblocks +=c[2]
        else:
            hexblocks +=c[2]
            hexblocks +=c[3]
        if count == 7 and j < (len(a)-1):         
            hexblocks +=", 0x"
            count=0
        else:
            count +=1
            
print(hexblocks)
# Out:
# 0x16081207080d0618, 0x0e14060e0e030b14, 0x020a080d13070812, 0x020e14111204000d, 0x03000b0b0e130704, 0x11020e1411120412, 0x0e05180e14110f11, 0x0e0611000c000102
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b66ae62c674f> in <module>
#      29
#      30 print(hexblocks)
# ---> 31 chr(hexblocks)
#
# TypeError: an integer is required (got type str)

# %%
chr(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-85749ab6af79> in <module>
# ----> 1 chr(b)
#
# NameError: name 'b' is not defined

# %%
qq= "WISHINGYOUGOODLUCKINTHISCOURSEANDALLOTHERCOURSESOFYOURPROGRAMABC"
a=qq.lower()

 
hexblocks = "0x"
count=0
kk=1 


for j in range(len(a)):     
        m = a[j]
        b=ord(m)-97         
      
        if kk>0:
            x = b
            c = hex(x)
         
        if x < 16 :
            hexblocks +='0'
            hexblocks +=c[2]
        else:
            hexblocks +=c[2]
            hexblocks +=c[3]
        if count == 7 and j < (len(a)-1):         
            hexblocks +=", 0x"
            count=0
        else:
            count +=1
            
print(hexblocks) 

from sage.crypto.block_cipher.des import DES 
des = DES()
plaintext=[0x16081207080d0618, 0x0e14060e0e030b14, 0x020a080d13070812, 0x020e14111204000d, 0x03000b0b0e130704, 0x11020e1411120412, 0x0e05180e14110f11, 0x0e0611000c191919]
key = 0x1F08260D1AC246E

def encrypt_des(plaintext, key): 
    p=plaintext
    k=key 
    ciphertext= ""

    for i in range (len(p)):
        c = des.encrypt(plaintext=p[i], key=k); 
        ciphertext += c.hex()
        ciphertext += ' '
    return ciphertext

encrypt_des(plaintext, key)

def decrypt_des(ciphertext, key):
    c=ciphertext
    k=key 
    plaintext= "0x"

    for i in range (len(c)):
        p = des.decrypt(ciphertext=c[i], key=k) 
        plaintext += p.hex()
        if i < (len(c)-1):
            plaintext += ', 0x' 
    return plaintext
ciphertext = [0xbe04aa776012718, 0x97eba93e1f59b88b, 0x4c67a13e0ac68d6a, 0x1b0e709c3e8dd55d, 0x64873df30f0092b1, 0x5bd820e90db96ec9, 0x14fc52b5446b1ba8, 0x5485af6f9884ab83]
key = 0x1F08260D1AC246E

decrypt_des(ciphertext, key)
# Out:
#   File "<ipython-input-13-6ee1fb7fae5c>", line 65
#     int(ciphertext[],Integer(16))
#                    ^
# SyntaxError: invalid syntax

# %%
def num_to_char(x):
    return alpha[x % 26]
st1='0x16081207080d0618, 0xe14060e0e030b14, 0x20a080d13070812, 0x20e14111204000d, 0x3000b0b0e130704, 0x11020e1411120412, 0xe05180e14110f11, 0xe0611000c191919'
for i in range(len(st1)):
            #q = int(st1[i],16)
            a = ord(st1[i])
            c=chr(a%26)
            #b += c
#print(q)  x等于数字120   逗号等于数字101
            print(a)
# Out:
# 48
# 120
# 49
# 54
# 48
# 56
# 49
# 50
# 48
# 55
# 48
# 56
# 48
# 100
# 48
# 54
# 49
# 56
# 44
# 32
# 48
# 120
# 101
# 49
# 52
# 48
# 54
# 48
# 101
# 48
# 101
# 48
# 51
# 48
# 98
# 49
# 52
# 44
# 32
# 48
# 120
# 50
# 48
# 97
# 48
# 56
# 48
# 100
# 49
# 51
# 48
# 55
# 48
# 56
# 49
# 50
# 44
# 32
# 48
# 120
# 50
# 48
# 101
# 49
# 52
# 49
# 49
# 49
# 50
# 48
# 52
# 48
# 48
# 48
# 100
# 44
# 32
# 48
# 120
# 51
# 48
# 48
# 48
# 98
# 48
# 98
# 48
# 101
# 49
# 51
# 48
# 55
# 48
# 52
# 44
# 32
# 48
# 120
# 49
# 49
# 48
# 50
# 48
# 101
# 49
# 52
# 49
# 49
# 49
# 50
# 48
# 52
# 49
# 50
# 44
# 32
# 48
# 120
# 101
# 48
# 53
# 49
# 56
# 48
# 101
# 49
# 52
# 49
# 49
# 48
# 102
# 49
# 49
# 44
# 32
# 48
# 120
# 101
# 48
# 54
# 49
# 49
# 48
# 48
# 48
# 99
# 49
# 57
# 49
# 57
# 49
# 57
